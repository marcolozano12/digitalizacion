# %% [markdown]
# <a href="https://colab.research.google.com/github/marcolozano12/digitalizacion/blob/main/ph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ph = float(input("dime el PH del elemento"))

if ph < 4:
  print("Es Muy ácido")
elif 4 <= ph < 7:
  print("Es Poco ácido")
elif ph == 7:
  print("Es neutro")
elif 7 < ph < 10:
  print("Es Poco Alcalino")
else:
  print("Es Muy Alcalino")
# Out:
# dime el PH del elemento7
# Es neutro
